# %%
# %load_ext cython

# %%
# %%cython
#
# import cython
#
# cimport numpy as np
#
# from cython.parallel import prange, parallel
#
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista, lc_rv_flags):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
# Out:
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:12:20: stop argument must be numeric
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:13: cimported module has no attribute 'isnan'
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:20: undeclared name not builtin: lc_rv_flags
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                       ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:23: undeclared name not builtin: ellc_f
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                      ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:38: undeclared name not builtin: t_calc
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:48: undeclared name not builtin: par
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:52: undeclared name not builtin: ipar
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                         ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:57: undeclared name not builtin: spar_1
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                                ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:64: undeclared name not builtin: spar_2
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:12: Assignment of Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:44: undeclared name not builtin: w_calc
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#        ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:8: undeclared name not builtin: flux
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#             ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:13: undeclared name not builtin: i_calc
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:12:20: stop may not be a Python object as we don't have the GIL
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#        ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:12:8: target may not be a Python object as we don't have the GIL
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#                   ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:19: Calling gil-requiring function not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#                               ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:31: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:20: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#                               ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:13:31: Constructing Python tuple not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                 ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:17: Discarding owned Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                 ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:17: Calling gil-requiring function not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                 ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:17: Constructing Python tuple not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                                         ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:41: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                              ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:30: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                                         ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:41: Constructing Python tuple not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# #with parallel(num_threads = process):
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#                                         ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:14:41: Constructing Python slice object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                     ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:37: Calling gil-requiring function not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                  ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:34: Accessing Python attribute not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                             ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:29: Accessing Python attribute not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                       ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:23: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                     ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:37: Constructing Python tuple not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:44: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                      ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:38: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:48: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                    ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:52: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                         ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:57: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#                                                                ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:15:64: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
# cdef magicFunction(lista):
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:16:12: Returning Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                   ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:19: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#             ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:13: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:12: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#        ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:8: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                   ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:19: Operation not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:12: Operation not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:12: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#        ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:8: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                   ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:19: Operation not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                           ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:43: Operation not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                      ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:38: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                           ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:27: Accessing Python global or builtin not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                      ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:38: Constructing Python tuple not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                                  ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:50: Indexing Python object not allowed without gil
#
# Error compiling Cython file:
# ------------------------------------------------------------
# ...
#     for j in prange(lista, schedule='dynamic', nogil=True):
#         if np.isnan(lc_rv_flags[j,0]):
#             print('Bad flux:',lc_rv_flags[j,:])
#             lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)
#             return -1
#         flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]
#                                            ^
# ------------------------------------------------------------
#
# /home/rhapy/.cache/ipython/cython/_cython_magic_55f695f9d5cadf700ed2fa95b43582fd.pyx:17:44: Accessing Python global or builtin not allowed without gil
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-3b44aede2873> in <module>()
# ----> 1 get_ipython().run_cell_magic('cython', '', "\nimport cython\n\ncimport numpy as np\n\nfrom cython.parallel import prange, parallel\n\n\n#with parallel(num_threads = process):\n \ncdef magicFunction(lista):\n    for j in prange(lista, schedule='dynamic', nogil=True):\n        if np.isnan(lc_rv_flags[j,0]):\n            print('Bad flux:',lc_rv_flags[j,:])\n            lc_dummy = ellc_f.ellc.lc(t_calc[j],par,ipar,spar_1,spar_2,9)\n            return -1\n        flux[i_calc[j]] += lc_rv_flags[j,0]*w_calc[j]")
#
# ~/Projects/EllcOpen/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-127> in cython(self, line, cell)
#
# ~/Projects/EllcOpen/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/Projects/EllcOpen/lib/python3.5/site-packages/Cython/Build/IpythonMagic.py in cython(self, line, cell)
#     313         if need_cythonize:
#     314             extensions = self._cythonize(module_name, code, lib_dir, args, quiet=quiet)
# --> 315             assert len(extensions) == 1
#     316             extension = extensions[0]
#     317             self._code_cache[key] = module_name
#
# TypeError: object of type 'NoneType' has no len()

# %%
magicFunction([1,2,3,4,5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2207745ead61> in <module>()
# ----> 1 magicFunction([1,2,3,4,5])
#
# <ipython-input-3-ae1b7228c759> in magicFunction(lista)
#       4
#       5 def magicFunction(lista):
# ----> 6     for j in prange(lista, schedule='dynamic', nogil=True):
#       7         if np.isnan(lc_rv_flags[j,0]):
#       8             print('Bad flux:',lc_rv_flags[j,:])
#
# NameError: name 'prange' is not defined
